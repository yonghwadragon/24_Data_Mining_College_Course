# %% [markdown]
# 3월 6일 OT \
# 그래프 마이닝, 네트워크 중요성, 동그라미와 선(뭐 있었음), 발표는 포장을 잘 해야함(앞뒤 스토리) \
# 그리고 수업 진행

# %% [markdown]
# 네트워크(=그래프), 상호 연결 관련, 노드와 링크로 표현,상호작용을 표현하고 연구 \

# %% [markdown]
# 3월 13일 \
# 결석이므로 따로 정리

# %% [markdown]
# 3월 20일 \
# 일단 수업

# %% [markdown]
# 4월 17일 \
# 갑작스러운 중간 정리

# %% [markdown]
# 5월 8일 \
# 기말 과제가 있긴합니다. 오늘 이론 많이 실습 함

# %% [markdown]
# 5월 22일 \
# 수업
